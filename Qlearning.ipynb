# %%
import gym
import numpy as np
import random

# %%
env = gym.make('FrozenLake-v1')

# %%
Q  = {}
for s in range(env.observation_space.n):
    for a in range(env.action_space.n):
        Q[(s,a)]  = 0.0

# %%
def epsilon_greedy(state, epsilon):
    if random.uniform(0,1) < epsilon:
        return env.action_space.sample()
    else:
        return max(list(range(env.action_space.n)), key = lambda x:
            Q[(state,x)])

# %%
alpha = 0.85
gamma = 0.90
epsilon = 0.8
num_episodes = 100000
num_timesteps = 5000

for i in range(num_episodes):
    s, info = env.reset()
    for t in range(num_timesteps):
        a = epsilon_greedy(s,epsilon)
        s_, r, done, _, _ = env.step(a)
        a_ = np.argmax([Q[s_, a] for a in range(env.action_space.n)])
        Q[(s,a)] += alpha * (r + gamma * Q[(s_,a_)]-Q[(s,a)])
        s = s_
        if done:
            break
for key, value in Q.items():
    print(key)
    print(value)
# Out:
# (0, 0)
# 0.3879970584893406
# (0, 1)
# 0.4038650217809889
# (0, 2)
# 0.5135789059883866
# (0, 3)
# 0.47276266462205707
# (1, 0)
# 0.060981420131343056
# (1, 1)
# 0.31752536601593395
# (1, 2)
# 0.011703598111930752
# (1, 3)
# 0.5360494568040184
# (2, 0)
# 0.4555003300772687
# (2, 1)
# 0.6794333558518516
# (2, 2)
# 0.32792926341161155
# (2, 3)
# 0.5332912707591118
# (3, 0)
# 0.03545853372435026
# (3, 1)
# 0.004319677755670725
# (3, 2)
# 0.004856927433160001
# (3, 3)
# 0.38474567693654804
# (4, 0)
# 0.4266627318387517
# (4, 1)
# 0.08942830657879774
# (4, 2)
# 0.36591721263950383
# (4, 3)
# 0.457391558109165
# (5, 0)
# 0.0
# (5, 1)
# 0.0
# (5, 2)
# 0.0
# (5, 3)
# 0.0
# (6, 0)
# 0.7686800724654242
# (6, 1)
# 0.007073329933348811
# (6, 2)
# 0.00025285235183126597
# (6, 3)
# 0.04386179367660989
# (7, 0)
# 0.0
# (7, 1)
# 0.0
# (7, 2)
# 0.0
# (7, 3)
# 0.0
# (8, 0)
# 0.5797877189547401
# (8, 1)
# 0.5219291877442448
# (8, 2)
# 0.5577016638576131
# (8, 3)
# 0.5227608497481663
# (9, 0)
# 0.11520100983657289
# (9, 1)
# 0.6235729129871916
# (9, 2)
# 0.6682502776686039
# (9, 3)
# 0.5303271061379933
# (10, 0)
# 0.39888426993061366
# (10, 1)
# 0.601846518510253
# (10, 2)
# 0.13052502159658663
# (10, 3)
# 0.07084137530631374
# (11, 0)
# 0.0
# (11, 1)
# 0.0
# (11, 2)
# 0.0
# (11, 3)
# 0.0
# (12, 0)
# 0.0
# (12, 1)
# 0.0
# (12, 2)
# 0.0
# (12, 3)
# 0.0
# (13, 0)
# 0.011661400576484765
# (13, 1)
# 0.8968219932688797
# (13, 2)
# 0.6659954735875284
# (13, 3)
# 0.8057137077209269
# (14, 0)
# 0.7148889462626845
# (14, 1)
# 0.9979548030408123
# (14, 2)
# 0.4957138013148962
# (14, 3)
# 0.7859835423328508
# (15, 0)
# 0.0
# (15, 1)
# 0.0
# (15, 2)
# 0.0
# (15, 3)
# 0.0

# %%
optimal_policy = np.zeros(16)
for i in range(16):
    best_value_i = 0
    for j in range(4):
        if best_value_i < Q[(i, j)]:
            best_value_i = Q[(i, j)]
            optimal_policy[i] = j
print(optimal_policy)
# Out:
# [2. 3. 1. 3. 3. 0. 0. 0. 0. 2. 1. 0. 0. 1. 1. 0.]
